# %%
from ultralytics import YOLO

# Load the model
model = YOLO('yolov8n.pt')  # you can use other model variants like yolov8s.pt, yolov8m.pt, etc.


model.train(data='/Users/saudahmad/Desktop/yolov8/data.yaml',
            epochs=5,
            imgsz=640,
            batch=64, 
            project='results',
            name='weed_detection',
            exist_ok=True,
            save_period=1)  # Saves checkpoints every 5 epochs
# Out:
# New https://pypi.org/project/ultralytics/8.3.15 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.2.75 🚀 Python-3.12.4 torch-2.2.2 CPU (Intel Core(TM) i7-1068NG7 2.30GHz)
# engine/trainer: task=detect, mode=train, model=yolov8n.pt, data=/Users/saudahmad/Desktop/yolov8/simple_weeds/data/data.yaml, epochs=5, time=None, patience=100, batch=64, imgsz=640, save=True, save_period=1, cache=False, device=None, workers=8, project=results, name=weed_detection, exist_ok=True, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, bgr=0.0, mosaic=1.0, mixup=0.0, copy_paste=0.0, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=results/weed_detection
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.12/site-packages/ultralytics/engine/trainer.py:529, in BaseTrainer.get_dataset(self)
#     523 elif self.args.data.split(".")[-1] in {"yaml", "yml"} or self.args.task in {
#     524     "detect",
#     525     "segment",
#     526     "pose",
#     527     "obb",
#     528 }:
# --> 529     data = check_det_dataset(self.args.data)
#     530     if "yaml_file" in data:
#
# File /opt/anaconda3/lib/python3.12/site-packages/ultralytics/data/utils.py:329, in check_det_dataset(dataset, autodownload)
#     328     m += f"\nNote dataset download directory is '{DATASETS_DIR}'. You can update this in '{SETTINGS_YAML}'"
# --> 329     raise FileNotFoundError(m)
#     330 t = time.time()
#
# FileNotFoundError:
# Dataset '/Users/saudahmad/Desktop/yolov8/simple_weeds/data/data.yaml' images not found ⚠️, missing path '/Users/saudahmad/Desktop/yolov8/simple_weeds/data/images/val'
# Note dataset download directory is '/Users/saudahmad/datasets'. You can update this in '/Users/saudahmad/Library/Application Support/Ultralytics/settings.yaml'
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[7], line 7
#       3 # Load the model
#       4 model = YOLO('yolov8n.pt')  # you can use other model variants like yolov8s.pt, yolov8m.pt, etc.
# ----> 7 model.train(data='/Users/saudahmad/Desktop/yolov8/simple_weeds/data/data.yaml',
#       8             epochs=5,
#       9             imgsz=640,
#      10             batch=64,
#      11             project='results',
#      12             name='weed_detection',
#      13             exist_ok=True,
#      14             save_period=1)
#
# File /opt/anaconda3/lib/python3.12/site-packages/ultralytics/engine/model.py:805, in Model.train(self, trainer, **kwargs)
#     802 if args.get("resume"):
#     803     args["resume"] = self.ckpt_path
# --> 805 self.trainer = (trainer or self._smart_load("trainer"))(overrides=args, _callbacks=self.callbacks)
#     806 if not args.get("resume"):  # manually set model only if not resuming
#     807     self.trainer.model = self.trainer.get_model(weights=self.model if self.ckpt else None, cfg=self.model.yaml)
#
# File /opt/anaconda3/lib/python3.12/site-packages/ultralytics/engine/trainer.py:134, in BaseTrainer.__init__(self, cfg, overrides, _callbacks)
#     132 self.model = check_model_file_from_stem(self.args.model)  # add suffix, i.e. yolov8n -> yolov8n.pt
#     133 with torch_distributed_zero_first(LOCAL_RANK):  # avoid auto-downloading dataset multiple times
# --> 134     self.trainset, self.testset = self.get_dataset()
#     135 self.ema = None
#     137 # Optimization utils init
#
# File /opt/anaconda3/lib/python3.12/site-packages/ultralytics/engine/trainer.py:533, in BaseTrainer.get_dataset(self)
#     531             self.args.data = data["yaml_file"]  # for validating 'yolo train data=url.zip' usage
#     532 except Exception as e:
# --> 533     raise RuntimeError(emojis(f"Dataset '{clean_url(self.args.data)}' error ❌ {e}")) from e
#     534 self.data = data
#     535 return data["train"], data.get("val") or data.get("test")
#
# RuntimeError: Dataset '/Users/saudahmad/Desktop/yolov8/simple_weeds/data/data.yaml' error ❌
# Dataset '/Users/saudahmad/Desktop/yolov8/simple_weeds/data/data.yaml' images not found ⚠️, missing path '/Users/saudahmad/Desktop/yolov8/simple_weeds/data/images/val'
# Note dataset download directory is '/Users/saudahmad/datasets'. You can update this in '/Users/saudahmad/Library/Application Support/Ultralytics/settings.yaml'

# %%
metrics = model.val(data='/Users/saudahmad/Desktop/yolov8/simple_weeds/data.yaml')
print(metrics)

# %%
# !pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in /opt/anaconda3/lib/python3.12/site-packages (4.10.0.84)
# Requirement already satisfied: numpy>=1.21.2 in /opt/anaconda3/lib/python3.12/site-packages (from opencv-python) (1.26.4)

# %%
import cv2
from ultralytics import YOLO


# Load the YOLOv8 model (replace 'best.pt' with the path to your trained model)
model = YOLO('/Users/saudahmad/Desktop/yolov8/simple_weeds/yolov8n.pt')

# Open a connection to the webcam
cap = cv2.VideoCapture(1)  # 0 is the default ID for the primary webcam

if not cap.isOpened():
    print("Error: Could not open webcam.")
    exit()

while True:
    # Capture frame-by-frame
    ret, frame = cap.read()
    if not ret:
        print("Error: Could not read frame.")
        break

    # Use the model to make predictions on the frame
    results = model(frame)
    
    # Loop through the detections and draw bounding boxes and labels on the frame
    for result in results:
        boxes = result.boxes.xyxy.numpy()  # get box coordinates
        confidences = result.boxes.conf.numpy()  # get confidence scores
        classes = result.boxes.cls.numpy().astype(int)  # get class indices

        for box, confidence, cls in zip(boxes, confidences, classes):
            x1, y1, x2, y2 = box.astype(int)
            label = f'{model.names[cls]} {confidence:.2f}'
            
            # Draw rectangle and label
            cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 2)
            cv2.putText(frame, label, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0, 255, 0), 2)

    # Display the resulting frame
    cv2.imshow('Webcam - YOLOv8', frame)
    
    # Break the loop on 'q' key press
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the webcam and close windows
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 416x640 1 person, 1 cup, 1 keyboard, 226.4ms
# Speed: 10.5ms preprocess, 226.4ms inference, 14.3ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 1 cup, 1 keyboard, 172.3ms
# Speed: 5.2ms preprocess, 172.3ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 1 cup, 1 keyboard, 169.3ms
# Speed: 2.8ms preprocess, 169.3ms inference, 1.4ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 1 cup, 1 keyboard, 196.8ms
# Speed: 5.0ms preprocess, 196.8ms inference, 0.8ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 1 cup, 1 keyboard, 105.0ms
# Speed: 3.0ms preprocess, 105.0ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 1 cup, 1 keyboard, 109.8ms
# Speed: 2.3ms preprocess, 109.8ms inference, 0.9ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 1 cup, 1 keyboard, 116.9ms
# Speed: 3.0ms preprocess, 116.9ms inference, 1.2ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 1 cup, 1 keyboard, 147.2ms
# Speed: 3.4ms preprocess, 147.2ms inference, 1.4ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 1 cup, 1 keyboard, 118.4ms
# Speed: 3.5ms preprocess, 118.4ms inference, 2.7ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 1 cup, 1 keyboard, 117.7ms
# Speed: 3.3ms preprocess, 117.7ms inference, 2.7ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 1 cup, 1 keyboard, 117.3ms
# Speed: 3.2ms preprocess, 117.3ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 1 cup, 1 keyboard, 118.9ms
# Speed: 4.0ms preprocess, 118.9ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 1 cup, 1 keyboard, 151.7ms
# Speed: 3.3ms preprocess, 151.7ms inference, 1.7ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 1 cup, 1 keyboard, 414.2ms
# Speed: 5.4ms preprocess, 414.2ms inference, 1.2ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 1 cup, 1 keyboard, 141.0ms
# Speed: 3.3ms preprocess, 141.0ms inference, 1.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 1 cup, 1 keyboard, 140.9ms
# Speed: 4.5ms preprocess, 140.9ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 1 cup, 2 keyboards, 106.8ms
# Speed: 3.4ms preprocess, 106.8ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 1 cup, 1 keyboard, 100.5ms
# Speed: 2.7ms preprocess, 100.5ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 1 cup, 1 keyboard, 99.3ms
# Speed: 2.7ms preprocess, 99.3ms inference, 0.9ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 persons, 1 cup, 1 laptop, 1 keyboard, 101.1ms
# Speed: 3.8ms preprocess, 101.1ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 3 persons, 1 cup, 1 laptop, 99.0ms
# Speed: 3.1ms preprocess, 99.0ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 3 persons, 1 cup, 1 laptop, 98.6ms
# Speed: 3.0ms preprocess, 98.6ms inference, 1.4ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 1 keyboard, 97.8ms
# Speed: 3.7ms preprocess, 97.8ms inference, 1.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 98.2ms
# Speed: 3.3ms preprocess, 98.2ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 1 remote, 102.3ms
# Speed: 2.6ms preprocess, 102.3ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 93.9ms
# Speed: 5.3ms preprocess, 93.9ms inference, 0.9ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 99.4ms
# Speed: 2.4ms preprocess, 99.4ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 96.1ms
# Speed: 2.4ms preprocess, 96.1ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 95.2ms
# Speed: 3.7ms preprocess, 95.2ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 96.2ms
# Speed: 2.7ms preprocess, 96.2ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 97.7ms
# Speed: 2.7ms preprocess, 97.7ms inference, 2.1ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 1 cup, 97.3ms
# Speed: 4.2ms preprocess, 97.3ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 107.4ms
# Speed: 3.6ms preprocess, 107.4ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 105.3ms
# Speed: 5.5ms preprocess, 105.3ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person,
8ms inference, 0.8ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 1 laptop, 151.8ms
# Speed: 14.6ms preprocess, 151.8ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 1 laptop, 194.4ms
# Speed: 1.8ms preprocess, 194.4ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 1 laptop, 198.0ms
# Speed: 2.7ms preprocess, 198.0ms inference, 0.8ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 1 laptop, 190.9ms
# Speed: 3.7ms preprocess, 190.9ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 1 laptop, 195.8ms
# Speed: 2.0ms preprocess, 195.8ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 1 laptop, 222.6ms
# Speed: 2.6ms preprocess, 222.6ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 1 laptop, 205.8ms
# Speed: 2.9ms preprocess, 205.8ms inference, 0.9ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 296.2ms
# Speed: 2.8ms preprocess, 296.2ms inference, 2.7ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 203.3ms
# Speed: 4.3ms preprocess, 203.3ms inference, 0.9ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 121.8ms
# Speed: 2.7ms preprocess, 121.8ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 119.2ms
# Speed: 2.5ms preprocess, 119.2ms inference, 0.9ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 205.1ms
# Speed: 1.6ms preprocess, 205.1ms inference, 1.7ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 132.1ms
# Speed: 1.8ms preprocess, 132.1ms inference, 1.2ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 133.9ms
# Speed: 2.9ms preprocess, 133.9ms inference, 2.2ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 213.6ms
# Speed: 2.0ms preprocess, 213.6ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 129.9ms
# Speed: 4.0ms preprocess, 129.9ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 132.4ms
# Speed: 2.7ms preprocess, 132.4ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 210.3ms
# Speed: 2.0ms preprocess, 210.3ms inference, 0.9ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 persons, 135.2ms
# Speed: 2.7ms preprocess, 135.2ms inference, 0.9ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 persons, 126.7ms
# Speed: 2.1ms preprocess, 126.7ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 148.5ms
# Speed: 1.8ms preprocess, 148.5ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 135.6ms
# Speed: 1.9ms preprocess, 135.6ms inference, 0.9ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 120.8ms
# Speed: 4.1ms preprocess, 120.8ms inference, 0.9ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 165.7ms
# Speed: 49.1ms preprocess, 165.7ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 106.1ms
# Speed: 3.9ms preprocess, 106.1ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 114.9ms
# Speed: 1.8ms preprocess, 114.9ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 231.2ms
# Speed: 2.2ms preprocess, 231.2ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 132.1ms
# Speed: 2.5ms preprocess, 132.1ms inference, 0.8ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 122.5ms
# Speed: 4.0ms preprocess, 122.5ms inference, 0.9ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 136.6ms
# Speed: 1.7ms preprocess, 136.6ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 168.4ms
# Speed: 30.1ms preprocess, 168.4ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 146.4ms
# Speed: 3.5ms preprocess, 146.4ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 1 laptop, 127.9ms
# Speed: 3.1ms preprocess, 127.9ms inference, 0.9ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 204.4ms
# Speed: 1.7ms preprocess, 204.4ms inference, 1.9ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 123.2ms
# Speed: 2.0ms preprocess, 123.2ms inference, 0.9ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 114.6ms
# Speed: 5.0ms preprocess, 114.6ms inference, 1.7ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 133.0ms
# Speed: 1.6ms preprocess, 133.0ms inference, 41.8ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 1 laptop, 117.0ms
# Speed: 2.7ms preprocess, 117.0ms inference, 0.8ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 116.6ms
# Speed: 1.9ms preprocess, 116.6ms inference, 0.9ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 122.0ms
# Speed: 2.9ms preprocess, 122.0ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 216.6ms
# Speed: 2.0ms preprocess, 216.6ms inference, 0.9ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 1 laptop, 128.2ms
# Speed: 3.1ms preprocess, 128.2ms inference, 2.2ms postprocess per image at shape (1, 3, 416, 640)

# %%
from inference_sdk import InferenceHTTPClient
import time

start_time = time.time()

CLIENT = InferenceHTTPClient(
    api_url="https://detect.roboflow.com",
    api_key="r1BvL5SHssBf78rJoCxf"
)

image_path = "/Users/saudahmad/Desktop/yolov8/simple_weeds/test/images/20210907_153931_x264_mp4-34_jpg.rf.379ce98bb5c004bc8bf2fdc22dbccf33.jpg"  # Replace with the actual path to your image
result = CLIENT.infer(image_path, model_id="weeds-nxe1w/1")

end_time = time.time()
elapsed_time = end_time - start_time

print(f"Elapsed time: {elapsed_time} seconds")
# Out:
# Elapsed time: 3.9585330486297607 seconds

# %%
from ultralytics import YOLO

model = YOLO('/Users/saudahmad/Desktop/yolov8/simple_weeds/yolov8n.pt')  # Load your trained model
model.export(format='onnx')  # Export to ONNX
# Out:
# Ultralytics YOLOv8.2.75 🚀 Python-3.12.4 torch-2.2.2 CPU (Intel Core(TM) i7-1068NG7 2.30GHz)
# YOLOv8n summary (fused): 168 layers, 3,151,904 parameters, 0 gradients, 8.7 GFLOPs
#
# PyTorch: starting from '/Users/saudahmad/Desktop/yolov8/simple_weeds/yolov8n.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 84, 8400) (6.2 MB)
# requirements: Ultralytics requirement ['onnx>=1.12.0'] not found, attempting AutoUpdate...
